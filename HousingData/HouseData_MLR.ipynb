# %%
# IMPORT DATA :

import pandas as pd
from sklearn import linear_model
from sklearn.model_selection import train_test_split


df =pd.read_csv("C:/Users/Michel/Documents/IntroML/HousingData/HousingData_post_treatment.csv")

df.head()
# Out:
#    Unnamed: 0      CRIM    ZN     INDUS  CHAS       NOX        RM       AGE  \
# 0           0  0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607
# 1           1  0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698
# 2           2  0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382
# 3           3  0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813
# 4           4  0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321
#
#         DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# 0  0.269203  0.000000  0.208015  0.287234  1.000000  0.089680  0.422222
# 1  0.348962  0.043478  0.104962  0.553191  1.000000  0.204470  0.368889
# 2  0.348962  0.043478  0.104962  0.553191  0.989737  0.063466  0.660000
# 3  0.448545  0.086957  0.066794  0.648936  0.994276  0.033389  0.631111
# 4  0.448545  0.086957  0.066794  0.648936  1.000000  0.303130  0.693333

# %% [markdown]
# For this database we have chosen to focus on explaining MEDV.

# %%
# Prepare Data :

x = df.drop('MEDV', axis=1)
y = df['MEDV']
 
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=42)

# %%
# Multi Linear Model :
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  0.4484390019297294
# Coefficients:
#  [-1.03637358e-04 -2.55898900e-01  7.95646628e-02 -4.46613702e-03
#   8.14030652e-02 -1.47497274e-01  5.18893977e-01 -6.73141052e-02
#  -3.58084009e-01  1.19838705e-01 -7.15490370e-02 -1.83685638e-01
#   1.04495591e-01 -3.84690966e-01]

# %%
# Graph :
from matplotlib import pyplot as plt 
import seaborn as sns 


y_pred = regr.predict(X_test)
plt.scatter(y_test, abs(y_pred - y_test) ,color='g') 



plt.show()

# %%
# RMSE :

from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_pred)
# Out:
# 0.011032550762419597

# %%
plt.matshow(df.corr())
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df, hue="MEDV")
##test
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Michel\Documents\IntroML\HousingData\HouseData_MLR.ipynb Cellule 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Michel/Documents/IntroML/HousingData/HouseData_MLR.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> sns.pairplot(df, hue="MEDV")
#
# File c:\Users\Michel\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File c:\Users\Michel\anaconda3\lib\site-packages\seaborn\axisgrid.py:2154, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2152 # Add a legend
#    2153 if hue is not None:
# -> 2154     grid.add_legend()
#    2156 grid.tight_layout()
#    2158 return grid
#
# File c:\Users\Michel\anaconda3\lib\site-packages\seaborn\axisgrid.py:165, in Grid.add_legend(self, legend_data, title, label_order, adjust_subtitles, **kwargs)
#     162     adjust_legend_subtitles(figlegend)
#     164 # Draw the plot to set the bounding boxes correctly
# --> 165 _draw_figure(self._figure)
#     167 # Calculate and set the new width of the figure so the legend fits
#     168 legend_width = figlegend.get_window_extent().width / self._figure.dpi
#
# File c:\Users\Michel\anaconda3\lib\site-packages\seaborn\utils.py:95, in _draw_figure(fig)
#      93 """Force draw of a matplotlib figure, accounting for back-compat."""
#      94 # See https://github.com/matplotlib/matplotlib/issues/19197 for context
# ---> 95 fig.canvas.draw()
#      96 if fig.stale:
#      97     try:
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\collections.py:991, in _CollectionWithSizes.draw(self, renderer)
#     988 @artist.allow_rasterization
#     989 def draw(self, renderer):
#     990     self.set_sizes(self._sizes, self.figure.dpi)
# --> 991     super().draw(renderer)
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\collections.py:405, in Collection.draw(self, renderer)
#     403 else:
#     404     combined_transform = transform
# --> 405 extents = paths[0].get_extents(combined_transform)
#     406 if (extents.width < self.figure.bbox.width
#     407         and extents.height < self.figure.bbox.height):
#     408     do_single_path_optimization = True
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\path.py:626, in Path.get_extents(self, transform, **kwargs)
#     624 else:
#     625     xys = []
# --> 626     for curve, code in self.iter_bezier(**kwargs):
#     627         # places where the derivative is zero can be extrema
#     628         _, dzeros = curve.axis_aligned_extrema()
#     629         # as can the ends of the curve
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\path.py:436, in Path.iter_bezier(self, **kwargs)
#     434 first_vert = None
#     435 prev_vert = None
# --> 436 for verts, code in self.iter_segments(**kwargs):
#     437     if first_vert is None:
#     438         if code != Path.MOVETO:
#
# File c:\Users\Michel\anaconda3\lib\site-packages\matplotlib\path.py:409, in Path.iter_segments(self, transform, remove_nans, clip, snap, stroke_width, simplify, curves, sketch)
#     407     for i in range(extra_vertices):
#     408         next(codes)
# --> 409         curr_vertices = np.append(curr_vertices, next(vertices))
#     410 yield curr_vertices, code
#
# File <__array_function__ internals>:5, in append(*args, **kwargs)
#
# File c:\Users\Michel\anaconda3\lib\site-packages\numpy\lib\function_base.py:4817, in append(arr, values, axis)
#    4815     values = ravel(values)
#    4816     axis = arr.ndim-1
# -> 4817 return concatenate((arr, values), axis=axis)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
