# %%
# IMPORT DATA :

import pandas as pd
from sklearn.model_selection import train_test_split


df =pd.read_csv("C:/Users/Michel/Documents/Github/IntroML/HousingData/HousingData_post_treatment.csv")

df.head()
# Out:
#    Unnamed: 0      CRIM    ZN     INDUS  CHAS       NOX        RM       AGE  \
# 0           0  0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607
# 1           1  0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698
# 2           2  0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382
# 3           3  0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813
# 4           4  0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321
#
#         DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# 0  0.269203  0.000000  0.208015  0.287234  1.000000  0.089680  0.422222
# 1  0.348962  0.043478  0.104962  0.553191  1.000000  0.204470  0.368889
# 2  0.348962  0.043478  0.104962  0.553191  0.989737  0.063466  0.660000
# 3  0.448545  0.086957  0.066794  0.648936  0.994276  0.033389  0.631111
# 4  0.448545  0.086957  0.066794  0.648936  1.000000  0.303130  0.693333

# %%
# Prepare Data :

x = df.drop('MEDV', axis=1)
y = df['MEDV']
 
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=42)

# %%
from sklearn.neighbors import KernelDensity
import numpy as np
rng = np.random.RandomState(42)
kde = KernelDensity(kernel='gaussian', bandwidth=0.5).fit(X_train,y_train)
y_pred=kde.predict(X_test)
log_density = kde.score_samples(X_train[:3])
y_pred
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Michel\Documents\GitHub\IntroML\Functions\HouseData_KDE.ipynb Cellule 3 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Michel/Documents/GitHub/IntroML/Functions/HouseData_KDE.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> rng = np.random.RandomState(42)
#       <a href='vscode-notebook-cell:/c%3A/Users/Michel/Documents/GitHub/IntroML/Functions/HouseData_KDE.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> kde = KernelDensity(kernel='gaussian', bandwidth=0.5).fit(X_train,y_train)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Michel/Documents/GitHub/IntroML/Functions/HouseData_KDE.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> y_pred=kde.predict(X_test)
#       <a href='vscode-notebook-cell:/c%3A/Users/Michel/Documents/GitHub/IntroML/Functions/HouseData_KDE.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> log_density = kde.score_samples(X_train[:3])
#       <a href='vscode-notebook-cell:/c%3A/Users/Michel/Documents/GitHub/IntroML/Functions/HouseData_KDE.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> y_pred
#
# AttributeError: 'KernelDensity' object has no attribute 'predict'
