# %%
#Users/Michel/Documents/GitHub/IntroML/Functions/
from MachineLearningFunctions import*

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
#df = pd.read_csv("C:/Users/Michel/Documents/GitHub/IntroML/HousingData/HousingData.csv")
df=pd.read_csv("C:/Users/Michel/Documents/GitHub/IntroML/ProstateCancer/prostatedata.csv", delim_whitespace=True)


df=df.drop('train', axis=1)
df.head()
# Out:
#      lcavol   lweight  age      lbph  svi       lcp  gleason  pgg45      lpsa
# 1 -0.579818  2.769459   50 -1.386294    0 -1.386294        6      0 -0.430783
# 2 -0.994252  3.319626   58 -1.386294    0 -1.386294        6      0 -0.162519
# 3 -0.510826  2.691243   74 -1.386294    0 -1.386294        7     20 -0.162519
# 4 -1.203973  3.282789   58 -1.386294    0 -1.386294        6      0 -0.162519
# 5  0.751416  3.432373   62 -1.386294    0 -1.386294        6      0  0.371564

# %%
#label="MEDV"
label='lpsa'
X,y=Data_treatment(df,label)
X
# Out:
# missing values filled
# categorical data binarised
# values normalized
#       lcavol   lweight       age      lbph  svi       lcp   gleason  pgg45
# 1   0.148460  0.164023  0.236842  0.000000  0.0  0.000000  0.000000    0.0
# 2   0.068269  0.392737  0.447368  0.000000  0.0  0.000000  0.000000    0.0
# 3   0.161810  0.131507  0.868421  0.000000  0.0  0.000000  0.333333    0.2
# 4   0.027689  0.377423  0.447368  0.000000  0.0  0.000000  0.000000    0.0
# 5   0.406048  0.439608  0.552632  0.000000  0.0  0.000000  0.000000    0.0
# ..       ...       ...       ...       ...  ...       ...       ...    ...
# 93  0.808297  0.624196  0.710526  0.000000  1.0  0.631180  0.333333    0.6
# 94  1.000000  0.632724  0.078947  0.000000  1.0  0.828664  0.333333    0.4
# 95  0.823231  0.424564  0.289474  0.000000  1.0  0.897374  0.333333    0.1
# 96  0.818416  0.581591  0.710526  0.793094  1.0  0.686276  0.333333    0.8
# 97  0.932463  0.665187  0.710526  0.491448  1.0  1.000000  0.333333    0.2
#
# [97 rows x 8 columns]

# %%
corr_matrix(df)

# %%
scatter_matrix(df,label)
